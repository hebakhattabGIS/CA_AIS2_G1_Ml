# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv('Titanic.csv')

# %%
df.drop('Ticket', axis =1)
x = df.drop('Survived', axis =1)
y = df['Survived']

# %%
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
num_cols = x.select_dtypes("number").columns
Scaler = MinMaxScaler()
Scaler.fit(x[num_cols])
x[num_cols] = Scaler.transform(x[num_cols])

# %%
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0       0.000000     1.0                            Braund, Mr. Owen Harris
# 1       0.001124     0.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       0.002247     1.0                             Heikkinen, Miss. Laina
# 3       0.003371     0.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.004494     1.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886     0.995506     0.5                              Montvila, Rev. Juozas
# 887     0.996629     0.0                       Graham, Miss. Margaret Edith
# 888     0.997753     1.0           Johnston, Miss. Catherine Helen "Carrie"
# 889     0.998876     0.0                              Behr, Mr. Karl Howell
# 890     1.000000     1.0                                Dooley, Mr. Patrick
#
# ...

# %%
#!pip install category_encoders
str_cols = x.select_dtypes('str').columns
str_cols= ['Sex',"Embarked"]

# %%
from category_encoders import OneHotEncoder
str_cols= ["Sex", "Embarked"] #x.select_dtypes("string").columns
encoder = OneHotEncoder(cols = str_cols, drop_invariant=True)
x = encoder.fit_transform(x)
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0       0.000000     1.0                            Braund, Mr. Owen Harris
# 1       0.001124     0.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       0.002247     1.0                             Heikkinen, Miss. Laina
# 3       0.003371     0.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.004494     1.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886     0.995506     0.5                              Montvila, Rev. Juozas
# 887     0.996629     0.0                       Graham, Miss. Margaret Edith
# 888     0.997753     1.0           Johnston, Miss. Catherine Helen "Carrie"
# 889     0.998876     0.0                              Behr, Mr. Karl Howell
# 890     1.000000     1.0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# linkedin post about our work & projects
# -listen to recording that will be sent and apply it. (assignment)
