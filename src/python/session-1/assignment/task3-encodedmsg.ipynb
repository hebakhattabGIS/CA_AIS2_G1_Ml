# %%
encodedmsg="&&&**$gnirtS PLIO!!@1234"

# %%
core = ''.join(ch for ch in encodedmsg if ch.isalpha() or ch == ' ').strip()
first, second = core.split()
decoded = first[::-1] + " " + second.replace("I", "E").replace("O", "U")
print(decoded)
# Out:
# String PLEU
