# %%
encodedmsg="##$$$@!yalpstcejorp EPUVT****9887"

# %%
core = ''.join(ch for ch in encodedmsg if ch.isalpha() or ch.isspace())
first, second = core.split()
decoded = first[::-1] + ' ' + ''.join({'E': 'A', 'U': 'O'}.get(ch, ch) for ch in second)
print(decoded)
# Out:
# projectsplay APOVT
