# %%
x=5
print(x)
# Out:
# 5

# %% [markdown]
# # welcome

# %%
x=10
id (x)
# Out:
# 140728623385304

# %%
x = 20 #this variable is age
y= 100

# %%
'''  
gjkdksudfielshudl
huilhdklsiuels
docstring is important
'''
print ("learning")
# Out:
# learning

# %%
name = "heba"
age = 30
course = "AI & machine learning"
print("my name is {} and my age is {} and i'm attending the {} course" .format(name, age, course))
# Out:
# my name is heba and my age is 30 and i'm attending the AI & machine learning course

# %%
print(f"my name is {name} and my age is {age}")
# Out:
# my name is heba and my age is 10

# %%
tup_1 = (1,2,3)
dict_1 = {'k1' : 30, 'k2' : 20, 'k3': 30}
print (type(dict_1))
# Out:
# <class 'dict'>

# %%
x = "depi for machine learning"
print(x[-1]) #- makes it count from the end of the string
type(x)
print (x[5:8:1])
print (x[::-1])
# Out:
# g
# for
# gninrael enihcam rof iped

# %%
name = "depi for machine learning for everyone"
capital = name.upper()
capital.lower()
# Out:
# 'depi for machine learning for everyone'

# %%
name = "depi learning"
name.replace("depi","machine")
name.capitalize()
# Out:
# 'Depi learning'

# %%
name = "depi for everyone"
name.title()
# Out:
# 'Depi For Everyone'

# %%
name = "depi for machine learning and depi for AI"
name.count("depi")
name.startswith ('depi')
# Out:
# True

# %%
name = "depi for machine learning and depi for AI"
x = name.split()
type(x)
x
#new_x = ''.join(x) not working
# Out:
# ['depi', 'for', 'machine', 'learning', 'and', 'depi', 'for', 'AI']

# %%
print ("hello world for \"students\" in depi")
# Out:
# hello world for "students" in depi

# %% [markdown]
# to comment or uncomment multiple lines use ctrl + ?
