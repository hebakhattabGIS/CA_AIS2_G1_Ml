# %%
import pandas as pd

data = [[1,444,"abc"],
        [2,555,"def"],
        [3,666,"ghi"],
        [4,444,"xyz"]]

# data = {'col1':[1,2,3,4],
#         'col2':[444,555,666,444],
#         'col3':['abc','def','ghi','xyz']}   
type(data)

df = pd.DataFrame(data)
df
# Out:
#    0    1    2
# 0  1  444  abc
# 1  2  555  def
# 2  3  666  ghi
# 3  4  444  xyz

# %%
cols = ['col1', 'col2', 'col3']
df = pd.DataFrame(data,columns = ['col1', 'col2', 'col3'])
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df[cols] = df[cols].astype('category')

# %%
df.describe(include='category')
# Out:
#         col1  col2 col3
# count      4     4    4
# unique     4     3    4
# top        1   444  abc
# freq       1     2    1

# %%
classification = df.col2.unique()
classification
# Out:
# [444, 555, 666]
# Categories (3, int64): [444, 555, 666]

# %%
#df[cols] = df[cols].astype('int')

#df['col2'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #df[cols] = df[cols].astype('int')
#       2
# ----> 3 df['col2'].min()
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\series.py:7802, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    7735 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="min")
#    7736 def min(
#    7737     self,
#    (...)   7741     **kwargs,
#    7742 ):
#    7743     """
#    7744     Return the minimum of the values over the requested axis.
#    7745
#    (...)   7800     0
#    7801     """
# -> 7802     return NDFrame.min(
#    7803         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    7804     )
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11781         skipna: bool = True,
#   11782         numeric_only: bool = False,
#   11783         **kwargs,
#   11784     ):
# > 11785         return self._stat_function(
#   11786             "min",
#   11787             nanops.nanmin,
#   11788             axis,
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11769         nv.validate_func(name, (), kwargs)
#   11770
#   11771         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11772
# > 11773         return self._reduce(
#   11774             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11775         )
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:2455, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2452 def _reduce(
#    2453     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2454 ):
# -> 2455     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2456     if name in ["argmax", "argmin"]:
#    2457         # don't wrap in Categorical!
#    2458         return result
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\base.py:2375, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    2370 if meth is None:
#    2371     raise TypeError(
#    2372         f"'{type(self).__name__}' with dtype {self.dtype} "
#    2373         f"does not support operation '{name}'"
#    2374     )
# -> 2375 result = meth(skipna=skipna, **kwargs)
#    2376 if keepdims:
#    2377     if name in ["min", "max"]:
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:2481, in Categorical.min(self, skipna, **kwargs)
#    2479 nv.validate_minmax_axis(kwargs.get("axis", 0))
#    2480 nv.validate_min((), kwargs)
# -> 2481 self.check_for_ordered("min")
#    2483 if not len(self._codes):
#    2484     return self.dtype.na_value
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:1965, in Categorical.check_for_ordered(self, op)
#    1963 """assert that we are ordered"""
#    1964 if not self.ordered:
# -> 1965     raise TypeError(
#    1966         f"Categorical is not ordered for operation {op}\n"
#    1967         "you can use .as_ordered() to change the "
#    1968         "Categorical to an ordered one\n"
#    1969     )
#
# TypeError: Categorical is not ordered for operation min
# you can use .as_ordered() to change the Categorical to an ordered one

# %%
def get_range(df):
    return df.max() - df.min()
get_range(df.col1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 def get_range(df):
#       2     return df.max() - df.min()
# ----> 3 get_range(df.col1)
#
# Cell In[16], line 2, in get_range(df)
#       1 def get_range(df):
# ----> 2     return df.max() - df.min()
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\series.py:7873, in Series.max(self, axis, skipna, numeric_only, **kwargs)
#    7806 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="max")
#    7807 def max(
#    7808     self,
#    (...)   7812     **kwargs,
#    7813 ):
#    7814     """
#    7815     Return the maximum of the values over the requested axis.
#    7816
#    (...)   7871     8
#    7872     """
# -> 7873     return NDFrame.max(
#    7874         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    7875     )
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\generic.py:11802, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11798         skipna: bool = True,
#   11799         numeric_only: bool = False,
#   11800         **kwargs,
#   11801     ):
# > 11802         return self._stat_function(
#   11803             "max",
#   11804             nanops.nanmax,
#   11805             axis,
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11769         nv.validate_func(name, (), kwargs)
#   11770
#   11771         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11772
# > 11773         return self._reduce(
#   11774             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11775         )
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:2455, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2452 def _reduce(
#    2453     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2454 ):
# -> 2455     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2456     if name in ["argmax", "argmin"]:
#    2457         # don't wrap in Categorical!
#    2458         return result
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\base.py:2375, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    2370 if meth is None:
#    2371     raise TypeError(
#    2372         f"'{type(self).__name__}' with dtype {self.dtype} "
#    2373         f"does not support operation '{name}'"
#    2374     )
# -> 2375 result = meth(skipna=skipna, **kwargs)
#    2376 if keepdims:
#    2377     if name in ["min", "max"]:
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:2513, in Categorical.max(self, skipna, **kwargs)
#    2511 nv.validate_minmax_axis(kwargs.get("axis", 0))
#    2512 nv.validate_max((), kwargs)
# -> 2513 self.check_for_ordered("max")
#    2515 if not len(self._codes):
#    2516     return self.dtype.na_value
#
# File ~\OneDrive\Desktop\CAI-S2-G1-AI\.venv-depi\Lib\site-packages\pandas\core\arrays\categorical.py:1965, in Categorical.check_for_ordered(self, op)
#    1963 """assert that we are ordered"""
#    1964 if not self.ordered:
# -> 1965     raise TypeError(
#    1966         f"Categorical is not ordered for operation {op}\n"
#    1967         "you can use .as_ordered() to change the "
#    1968         "Categorical to an ordered one\n"
#    1969     )
#
# TypeError: Categorical is not ordered for operation max
# you can use .as_ordered() to change the Categorical to an ordered one
