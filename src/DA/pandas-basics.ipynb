# %%
import pandas as pd

s = pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#specify the index
s = pd.Series([1,2,3,4], index = ["A", "B", "C", "D"])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data = [[1,444,"abc"],
        [2,555,"def"],
        [3,666,"ghi"],
        [4,444,"xyz"]]

# data = {'col1':[1,2,3,4],
#         'col2':[444,555,666,444],
#         'col3':['abc','def','ghi','xyz']}   
type(data)
# Out:
# list

# %%
df = pd.DataFrame(data)
df
# Out:
#    0    1    2
# 0  1  444  abc
# 1  2  555  def
# 2  3  666  ghi
# 3  4  444  xyz

# %%
cols = ['col1', 'col2', 'col3']
df = pd.DataFrame(data,columns = ['col1', 'col2', 'col3'])
df
#df.dtypes
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
#cols = ['id', 'sal']
#df[cols] = df[cols].astype('category')
df.dtypes #check from the slides
# Out:
# col1    int64
# col2    int64
# col3      str
# dtype: object

# %%
#df.head(2) #check from the lect slides
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head(2)
#
# NameError: name 'df' is not defined
