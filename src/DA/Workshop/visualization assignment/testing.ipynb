# %%
from config import config
import preprocessing
dftest = preprocessing.Read_data_file(config.fpath)
dftest
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
preprocessing.check_outliers(dftest)
# Out:
# Column: age
# Q1=27.0, Q3=51.0, IQR=24.0
# Lower fence=-9.0, Upper fence=87.0
# age lower outliers:
#  []
# age upper outliers:
#  []
#
# Column: bmi
# Q1=26.29625, Q3=34.69375, IQR=8.3975
# Lower fence=13.7, Upper fence=47.290000000000006
# bmi lower outliers:
#  []
# bmi upper outliers:
#  [49.06 48.07 47.52 47.41 50.38 47.6  52.58 47.74 53.13]
#
# Column: children
# Q1=0.0, Q3=2.0, IQR=2.0
# Lower fence=-3.0, Upper fence=5.0
# children lower outliers:
#  []
# children upper outliers:
#  []
#
# Column: charges
# Q1=4740.28715, Q3=16639.912515, IQR=11899.625365
# Lower fence=-13109.1508975, Upper fence=34489.350562499996
# charges lower outliers:
#  []
# charges upper outliers:
#  [39611.7577  36837.467   37701.8768  38711.      35585.576   51194.55914
#  39774.2763  48173.361   38709.176   37742.5757  47496.49445 37165.1638
#  39836.519   43578.9394  47291.055   47055.5321  39556.4945  40720.55105
#  36950.2567  36149.4835  48824.45    43753.33705 37133.8982  34779.615
# ...

# %%
preprocessing.plot_piechart(dftest, config.CAT_COLS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 preprocessing.plot_piechart(dftest, config.CAT_COLS)
#
# AttributeError: module 'preprocessing' has no attribute 'plot_piechart'
